# %% [markdown]
# <a href="https://colab.research.google.com/github/key-cc/c3d-pytorch/blob/master/c3d_hockey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /home
# Out:
# /home

# %%
# !git clone https://github.com/key-cc/c3d-pytorch.git
# Out:
# Cloning into 'c3d-pytorch'...
# remote: Enumerating objects: 34998, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 34998 (delta 20), reused 0 (delta 0), pack-reused 34954
# Receiving objects: 100% (34998/34998), 360.45 MiB | 50.45 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
cd /home/c3d-pytorch
# Out:
# /home/c3d-pytorch

# %%
mkdir data

# %%
mkdir video

# %%
# !cp -r /content/drive/MyDrive/MasterThesis/3dcnn_rocketfight/changed_hockeyzip/HockeyFights.zip /home/c3d-pytorch/video

# %%
cd video
# Out:
# /home/c3d-pytorch/video

# %%
# !unzip HockeyFights.zip

# %%
# !rm -rf /home/c3d-pytorch/video/HockeyFights.zip

# %%
cd /home/c3d-pytorch
# Out:
# /home/c3d-pytorch

# %%
# !python3 extract_frames.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Creating file... ./data/no462_xvid/39.jpg
# Creating file... ./data/no462_xvid/40.jpg
#
# begin to deal with the  885 -th video ：fi73_xvid.avi
# Creating file... ./data/fi73_xvid/0.jpg
# Creating file... ./data/fi73_xvid/1.jpg
# Creating file... ./data/fi73_xvid/2.jpg
# Creating file... ./data/fi73_xvid/3.jpg
# Creating file... ./data/fi73_xvid/4.jpg
# Creating file... ./data/fi73_xvid/5.jpg
# Creating file... ./data/fi73_xvid/6.jpg
# Creating file... ./data/fi73_xvid/7.jpg
# Creating file... ./data/fi73_xvid/8.jpg
# Creating file... ./data/fi73_xvid/9.jpg
# Creating file... ./data/fi73_xvid/10.jpg
# Creating file... ./data/fi73_xvid/11.jpg
# Creating file... ./data/fi73_xvid/12.jpg
# Creating file... ./data/fi73_xvid/13.jpg
# Creating file... ./data/fi73_xvid/14.jpg
# Creating file... ./data/fi73_xvid/15.jpg
# Creating file... ./data/fi73_xvid/16.jpg
# Creating file... ./data/fi73_xvid/17.jpg
# Creating file... ./data/fi73_xvid/18.jpg
# ...

# %%
# !python3 hockey_data.py
# Out:
# tcmalloc: large alloc 1478402048 bytes == 0x5ce8000 @  0x7f5c39512001 0x7f5c34fad1af 0x7f5c35003c23 0x7f5c35004a87 0x7f5c350a6823 0x58f62c 0x510bf2 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82 0x64dd2e 0x7f5c3910dc87 0x5b636a
# (1000, 16, 3, 70, 110)
# (1000,)
# (200, 16, 3, 70, 110)
# (200,)

# %%
# !python3 hockey_model.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# [2022-10-19 00:11:44,221][INFO] lr_rate: 0.0001
#
# [2022-10-19 00:11:44,221][INFO] Train_Loss: 0.007735      Train_Acc: 92.900%
#
# [2022-10-19 00:11:44,221][INFO] -----------------------------------------------------------------------------------------------------------
# [2022-10-19 00:11:44,456][INFO] Test_Loss: 0.007582      Test_Acc: 93.500%
#
# [2022-10-19 00:11:44,456][INFO] --------------------------------------------------------
# [2022-10-19 00:11:44,457][INFO] start training!
# [2022-10-19 00:11:44,588][INFO] Train Epoch: 105  [0/1000 (0%)]     Batch_Loss: 0.008909       Batch_Acc: 86.000%
# [2022-10-19 00:11:44,588][INFO] -----------------------------------------------------------------------------------------------------------
# [2022-10-19 00:11:44,715][INFO] Train Epoch: 105  [50/1000 (5%)]     Batch_Loss: 0.007348       Batch_Acc: 96.000%
# ...

# %%
# !cp -r /home/c3d-pytorch/model_checkpoints /content/drive/MyDrive/MasterThesis/3dcnn_rocketfight/c3dhockeycheckpoint

# %%
# !cp -r /home/c3d-pytorch/C3D_hockeyFight.log /content/drive/MyDrive/MasterThesis/3dcnn_rocketfight/c3dhockeycheckpoint

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path.eps', format='eps', dpi=1000)
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d26a3e52984c> in <module>
# ----> 1 plt.plot(history.history['accuracy'])
#       2 plt.plot(history.history['val_accuracy'])
#       3 plt.title('model accuracy')
#       4 plt.ylabel('accuracy')
#       5 plt.xlabel('epoch')
#
# NameError: name 'plt' is not defined
